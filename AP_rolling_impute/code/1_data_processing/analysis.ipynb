# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_feather("/project/dachxiu/haohu/Weak_signal/finance2/data1957-2022_raw/chars_raw_imputed.feather")

# %%
df.date.min()
# Out:
# Timestamp('1950-11-30 00:00:00')

# %%
df['ret']
# Out:
# 0          0.365385
# 1         -0.098592
# 2         -0.222656
# 3         -0.005025
# 4         -0.080808
#              ...
# 3028225   -0.077391
# 3028226    0.221942
# 3028227   -0.045025
# 3028228    0.381469
# 3028229    0.170008
# Name: ret, Length: 3028230, dtype: float64

# %%
df['roic'].head(20)
# Out:
# 0    -0.608696
# 1    -0.608696
# 2    -0.608696
# 3    -0.608696
# 4    -0.608696
# 5    -0.608696
# 6    -0.608696
# 7    -0.608696
# 8    -0.608696
# 9    -0.608696
# 10   -0.608696
# 11   -0.608696
# 12   -0.401811
# 13   -0.401811
# 14   -0.401811
# 15    0.122651
# 16    0.122651
# 17    0.122651
# 18    0.122651
# 19    0.122651
# Name: roic, dtype: float64

# %% [markdown]
# note: 这里的date对应的return的date，其他的features都是lag过的

# %%
abs(df['prc'])
# Out:
# 0            3.25000
# 1            4.43750
# 2            4.00000
# 3            3.10938
# 4            3.09375
#              ...
# 3028225    232.07001
# 3028226    214.11000
# 3028227    261.63000
# 3028228    249.85001
# 3028229    345.16000
# Name: prc, Length: 3028230, dtype: float64

# %%
df[['prc','shrout','permno','date','ticker']]
# Out:
#                prc     shrout  permno       date ticker
# 0         -3.25000     3680.0   10000 1986-03-31  OMFGA
# 1         -4.43750     3680.0   10000 1986-04-30  OMFGA
# 2         -4.00000     3793.0   10000 1986-05-31  OMFGA
# 3         -3.10938     3793.0   10000 1986-06-30  OMFGA
# 4         -3.09375     3793.0   10000 1986-07-31  OMFGA
# ...            ...        ...     ...        ...    ...
# 3028225  232.07001  3194640.0   93436 2024-08-31   TSLA
# 3028226  214.11000  3194640.0   93436 2024-09-30   TSLA
# 3028227  261.63000  3207000.0   93436 2024-10-31   TSLA
# 3028228  249.85001  3210060.0   93436 2024-11-30   TSLA
# 3028229  345.16000  3210060.0   93436 2024-12-31   TSLA
#
# [3028230 rows x 5 columns]

# %%
df.columns.tolist()
# Out:
# ['gvkey',
#  'permno',
#  'ticker',
#  'conm',
#  'comnam',
#  'sic',
#  'ret',
#  'exchcd',
#  'shrcd',
#  'prc',
#  'shrout',
#  'adm',
#  'herf',
#  'hire',
#  'absacc',
#  'age',
#  'chempia',
#  'chinv',
#  'convind',
#  'currat',
#  'divi',
#  'divo',
#  'grcapx',
#  'pchcapx_ia',
#  'pchcurrat',
#  'pchdepr',
#  'pchgm_pchsale',
#  'pchquick',
#  'pchsale_pchinvt',
#  'pchsale_pchrect',
#  'pchsale_pchxsga',
#  'pchsaleinv',
#  'quick',
#  'realestate',
#  'roic',
#  'salecash',
#  'salerec',
#  'saleinv',
#  'secured',
#  'securedind',
#  'sin',
#  'tang',
#  'tb',
#  'chpmia',
#  'baspread',
#  'beta',
#  'ill',
#  'maxret',
#  'mom12m',
#  'mom1m',
#  'mom36m',
#  'mom60m',
#  'mom6m',
#  're',
#  'rvar_capm',
#  'rvar_ff3',
#  'rvar_mean',
#  'seas1a',
#  'std_dolvol',
#  'std_turn',
#  'zerotrade',
#  'me',
#  'dy',
#  'turn',
#  'dolvol',
#  'indmom',
#  'abr',
#  'sue',
#  'cinvest',
#  'nincr',
#  'pscore',
#  'roavol',
#  'stdacc',
#  'stdcf',
#  'acc',
#  'bm',
# ...

# %%
df['me']
# Out:
# 0          1.196000e+01
# 1          1.633000e+01
# 2          1.517200e+01
# 3          1.179388e+01
# 4          1.173459e+01
#                ...
# 3028225    7.413801e+05
# 3028226    6.840044e+05
# 3028227    8.390474e+05
# 3028228    8.020335e+05
# 3028229    1.107984e+06
# Name: me, Length: 3028230, dtype: float64
